# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,4,9,16])

# %%
plt.show()

# %%
import numpy as np
x=np.linspace(0,10,20)

# %%
y=x**2.0
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
plt.plot(x,y);

# %%
x=np.linspace(0,10,20)
y1=x**2.0
y2=x**1.5
plt.plot(x,y1,"bo-")

# %%
plt.plot(x,y1,"bo-",linewidth=2,markersize=12)

# %%
plt.plot(x,y2,"gs-",linewidth=2,markersize=12)

# %%
x=np.linspace(0,10,20)
y1=x**2.0
y2=x**1.5

plt.plot(x,y1,"bo-",linewidth=2,markersize=12)
plt.plot(x,y2,"gs-",linewidth=2,markersize=12)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
x=np.linspace(0,10,20)
y1=x**2.0
y2=x**1.5

plt.plot(x,y1,"bo-",linewidth=2,markersize=12, label="first")
plt.plot(x,y2,"gs-",linewidth=2,markersize=12 ,label="second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper left")
plt.savefig("myplot.pdf")

# %%
x=np.linspace(0,10,20)
y1=x**2.0
y2=x**1.5

plt.loglog(x,y1,"bo-",linewidth=2,markersize=12, label="first")
plt.loglog(x,y2,"gs-",linewidth=2,markersize=12 ,label="second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper left")
# Out:
# <ipython-input-32-cba708809ca4>:9: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([-0.5,10.5,-5,105])
# <ipython-input-32-cba708809ca4>:9: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([-0.5,10.5,-5,105])

# %%
x=np.logspace(-1,1,40)
y1=x**2.0
y2=x**1.5

plt.loglog(x,y1,"bo-",linewidth=2,markersize=12, label="first")
plt.loglog(x,y2,"gs-",linewidth=2,markersize=12 ,label="second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper left")
# Out:
# <ipython-input-34-77a35d5acdae>:9: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([-0.5,10.5,-5,105])
# <ipython-input-34-77a35d5acdae>:9: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.axis([-0.5,10.5,-5,105])

# %%
np.random.normal(size=1000)
plt.hist(x);

# %%
plt.hist(x,normed=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-090c7cb9b4ce> in <module>
# ----> 1 plt.hist(x,normed=True);
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813             if patch:
#    6814                 p = patch[0]
# -> 6815                 p.update(kwargs)
#    6816                 if lbl is not None:
#    6817                     p.set_label(lbl)
#
# D:\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
plt.hist(x,normed=True, bins=np.linspace(-5,5,21));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-efdffe909be4> in <module>
# ----> 1 plt.hist(x,normed=True, bins=np.linspace(-5,5,21));
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813             if patch:
#    6814                 p = patch[0]
# -> 6815                 p.update(kwargs)
#    6816                 if lbl is not None:
#    6817                     p.set_label(lbl)
#
# D:\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
x=np.random.gamma(2,3,100000)
plt.hist(x,bins=30)
# Out:
# (array([1.0395e+04, 1.9369e+04, 1.8929e+04, 1.5233e+04, 1.1339e+04,
#         8.1740e+03, 5.7190e+03, 3.8680e+03, 2.5430e+03, 1.6160e+03,
#         1.0480e+03, 6.1300e+02, 4.0400e+02, 2.8600e+02, 1.8100e+02,
#         1.1300e+02, 7.3000e+01, 3.1000e+01, 2.7000e+01, 1.8000e+01,
#         9.0000e+00, 2.0000e+00, 7.0000e+00, 0.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([3.90779425e-03, 1.63281490e+00, 3.26172201e+00, 4.89062912e+00,
#         6.51953623e+00, 8.14844334e+00, 9.77735044e+00, 1.14062576e+01,
#         1.30351647e+01, 1.46640718e+01, 1.62929789e+01, 1.79218860e+01,
#         1.95507931e+01, 2.11797002e+01, 2.28086073e+01, 2.44375144e+01,
#         2.60664215e+01, 2.76953286e+01, 2.93242357e+01, 3.09531429e+01,
#         3.25820500e+01, 3.42109571e+01, 3.58398642e+01, 3.74687713e+01,
#         3.90976784e+01, 4.07265855e+01, 4.23554926e+01, 4.39843997e+01,
#         4.56133068e+01, 4.72422139e+01, 4.88711210e+01]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(x,bins=30,cumulative=True,normed=True,histtype="step")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-81db2ec87ea9> in <module>
# ----> 1 plt.hist(x,bins=30,cumulative=True,normed=True,histtype="step")
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813             if patch:
#    6814                 p = patch[0]
# -> 6815                 p.update(kwargs)
#    6816                 if lbl is not None:
#    6817                     p.set_label(lbl)
#
# D:\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
plt.figure()
plt.subplot(221)
plt.hist(x,bins=30)
plt.subplot(222)

plt.hist(x,bins=30,cumulative=30)
plt.subplot(224)
plt.hist(x,bins=30,normed=True,cumulative=True,histtype="step")
plt.subplot(223)
plt.hist(x,bins=30,normed=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-fd330bbe7fb8> in <module>
#       6 plt.hist(x,bins=30,cumulative=30)
#       7 plt.subplot(224)
# ----> 8 plt.hist(x,bins=30,normed=True,cumulative=True,histtype="step")
#       9 plt.subplot(223)
#      10 plt.hist(x,bins=30,normed=True)
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813             if patch:
#    6814                 p = patch[0]
# -> 6815                 p.update(kwargs)
#    6816                 if lbl is not None:
#    6817                     p.set_label(lbl)
#
# D:\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
plt.plot([0,1,2],[0,1,4],"rd-")

# %%
x=np.logspace(0,1,10)
y=x**2
plt.loglog(x,y,"bo-")

# %%
np.linspace(-5,5,21)
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
np.linspace(-5,5,201)
# Out:
# array([-5.  , -4.95, -4.9 , -4.85, -4.8 , -4.75, -4.7 , -4.65, -4.6 ,
#        -4.55, -4.5 , -4.45, -4.4 , -4.35, -4.3 , -4.25, -4.2 , -4.15,
#        -4.1 , -4.05, -4.  , -3.95, -3.9 , -3.85, -3.8 , -3.75, -3.7 ,
#        -3.65, -3.6 , -3.55, -3.5 , -3.45, -3.4 , -3.35, -3.3 , -3.25,
#        -3.2 , -3.15, -3.1 , -3.05, -3.  , -2.95, -2.9 , -2.85, -2.8 ,
#        -2.75, -2.7 , -2.65, -2.6 , -2.55, -2.5 , -2.45, -2.4 , -2.35,
#        -2.3 , -2.25, -2.2 , -2.15, -2.1 , -2.05, -2.  , -1.95, -1.9 ,
#        -1.85, -1.8 , -1.75, -1.7 , -1.65, -1.6 , -1.55, -1.5 , -1.45,
#        -1.4 , -1.35, -1.3 , -1.25, -1.2 , -1.15, -1.1 , -1.05, -1.  ,
#        -0.95, -0.9 , -0.85, -0.8 , -0.75, -0.7 , -0.65, -0.6 , -0.55,
#        -0.5 , -0.45, -0.4 , -0.35, -0.3 , -0.25, -0.2 , -0.15, -0.1 ,
#        -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,
#         0.4 ,  0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,
#         0.85,  0.9 ,  0.95,  1.  ,  1.05,  1.1 ,  1.15,  1.2 ,  1.25,
#         1.3 ,  1.35,  1.4 ,  1.45,  1.5 ,  1.55,  1.6 ,  1.65,  1.7 ,
#         1.75,  1.8 ,  1.85,  1.9 ,  1.95,  2.  ,  2.05,  2.1 ,  2.15,
#         2.2 ,  2.25,  2.3 ,  2.35,  2.4 ,  2.45,  2.5 ,  2.55,  2.6 ,
#         2.65,  2.7 ,  2.75,  2.8 ,  2.85,  2.9 ,  2.95,  3.  ,  3.05,
#         3.1 ,  3.15,  3.2 ,  3.25,  3.3 ,  3.35,  3.4 ,  3.45,  3.5 ,
#         3.55,  3.6 ,  3.65,  3.7 ,  3.75,  3.8 ,  3.85,  3.9 ,  3.95,
#         4.  ,  4.05,  4.1 ,  4.15,  4.2 ,  4.25,  4.3 ,  4.35,  4.4 ,
#         4.45,  4.5 ,  4.55,  4.6 ,  4.65,  4.7 ,  4.75,  4.8 ,  4.85,
#         4.9 ,  4.95,  5.  ])

# %%
plt.subplot(333)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(3,3,3)
# Out:
# <AxesSubplot:>
